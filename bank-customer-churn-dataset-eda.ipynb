# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bank-customer-churn-dataset/Bank Customer Churn Prediction.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Here,the dataset will be in the .csv file and to convert in to pandas .read_csv() is used.In the brackets we will give path of the dataset so that which it means dataset from csv to pandas and we will print the data by giving data in the next line and it prints all the values of the dataset including all columns and rows.**

# %%
df=pd.read_csv("/kaggle/input/bank-customer-churn-dataset/Bank Customer Churn Prediction.csv")
df
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %% [markdown]
# **data.head() will prints the first 5 observations of the dataset which means like head is at the top and after printing we can see the first 5 observations as output.**

# %%
df.tail()
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 9995                2            1              0          96270.64      0
# 9996                1            1              1         101699.77      0
# 9997                1            0              1          42085.58      1
# 9998                2            1              0          92888.52      1
# 9999                1            1              0          38190.78      0

# %% [markdown]
# **data.tail() will prints the last 5 observations of the dataset which means like tail is at the back and after printing we can see the last 5 observations as output.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# **data.info() function is used to find all the information of the dataset.after printing the output we can see that the information of all the 12 coloumns are provided and the information about each coloumn describes about them.for example,lets take first coloumn i.e.customer id and it has no null values and the data type is integer and describes as int64 which means integer of type 64 bits.similarly for all the coloumns and at the end it shows count of each data type.It has 2 data types of float of 64 bits and 8 int64 and 2 objects.**

# %%
 df.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %% [markdown]
# **Here is null is used to find the null values of the respected columns data and isnull().sum() is to find the total null values that are there in the respected coloumn of the dataset and the datatype is integer and it is shown as int64 because of we are counting the no of null values and the count replicates in the result if there are null values in respected coloumn of the dataset**

# %%
from datetime import date
date.today().year
df['birth year']=date.today().year-df['age']
df
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn  \
# ...

# %% [markdown]
# **Here by using the coloumns present in the dataset we can create some more coloumns by using them and as we see age is there in the dataset and by using it we can find the birth year of the each candidate and i imported date and by the date i have found out present year and the age is subracted from the present year which gives the birth year.**

# %%
df.shape
# Out:
# (10000, 13)

# %% [markdown]
# **By using shape we can find the no of rows and coloumns and at the start we know it has 10000 rows and 12 coloumns and now by adding extra coloumn in the form of birth year we have 13 coloumns and it is given as output as shown above.**

# %%
df.describe().T
# Out:
#                     count          mean           std          min  \
# customer_id       10000.0  1.569094e+07  71936.186123  15565701.00
# credit_score      10000.0  6.505288e+02     96.653299       350.00
# age               10000.0  3.892180e+01     10.487806        18.00
# tenure            10000.0  5.012800e+00      2.892174         0.00
# balance           10000.0  7.648589e+04  62397.405202         0.00
# products_number   10000.0  1.530200e+00      0.581654         1.00
# credit_card       10000.0  7.055000e-01      0.455840         0.00
# active_member     10000.0  5.151000e-01      0.499797         0.00
# estimated_salary  10000.0  1.000902e+05  57510.492818        11.58
# churn             10000.0  2.037000e-01      0.402769         0.00
# birth year        10000.0  1.984078e+03     10.487806      1931.00
#
#                           25%           50%           75%          max
# customer_id       15628528.25  1.569074e+07  1.575323e+07  15815690.00
# ...

# %% [markdown]
# **describe() function is used to find out the statistics values which includes mean,count,std,min,25%,50%,75%,max and here it chooses only of datatypes integer or float values or numerical data types.To include including non numerical data the following change in the code requires from the previous ones.**

# %%
df.describe(include='all').T
# Out:
#                     count unique     top  freq           mean           std  \
# customer_id       10000.0    NaN     NaN   NaN  15690940.5694  71936.186123
# credit_score      10000.0    NaN     NaN   NaN       650.5288     96.653299
# country             10000      3  France  5014            NaN           NaN
# gender              10000      2    Male  5457            NaN           NaN
# age               10000.0    NaN     NaN   NaN        38.9218     10.487806
# tenure            10000.0    NaN     NaN   NaN         5.0128      2.892174
# balance           10000.0    NaN     NaN   NaN   76485.889288  62397.405202
# products_number   10000.0    NaN     NaN   NaN         1.5302      0.581654
# credit_card       10000.0    NaN     NaN   NaN         0.7055       0.45584
# active_member     10000.0    NaN     NaN   NaN         0.5151      0.499797
# estimated_salary  10000.0    NaN     NaN   NaN  100090.239881  57510.492818
# ...

# %% [markdown]
# **Here,from the previous one we came to know that by including non numerical data it gives three more extra features unique,top,freq which will be used for non numerical data types and rest of the data types have null values and similarly for the other ones it shows values and for the non numerical it shows null values.**

# %%
df['birth year'].unique()
df
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn  \
# ...

# %% [markdown]
# **Here i have taken unique function which gives unique values i.e.only one value and i have taken birth year where i have found out in which only one customer was born and i have printed out the values of that birth years which is shown in the output.**

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,5,1)
df.boxplot(column=['credit_score'])
plt.subplot(1,5,2)
df.boxplot(column=['age'])
plt.subplot(1,5,3)
df.boxplot(column=['tenure'])
plt.subplot(1,5,4)
df.boxplot(column=['balance'])
plt.subplot(1,5,5)
df.boxplot(column=['estimated_salary'])
plt.show()

# %% [markdown]
# **A box and whisker plot or diagram, is a graph summarising a set of data.The shape of the boxplot shows how the data is distributed and it also shows any outliers.  The line splitting the box in two represents the median value. This shows that 50% of the data lies on the left hand side of the median value and 50% lies on the right hand side.The values at which the horizontal lines stop at are the values of the upper and lower values of the data. The single points on the diagram show the outliers.
# The bottom edge of the box represents the lower quartile; it shows the value at which the first 25% of the data falls up to. The top edge of the box shows the upper quartile; it shows that
# 25% of the data lies to the top of the upper quartile value.**

# %%
df['age'].value_counts()
# Out:
# age
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 92      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# **Here in the dataset we are taking age as a parameter and we are counting the no of same aged ones wheter they are only one or there are multiple ones and the output is shown above**

# %%
df["age"].hist()
# Out:
# <Axes: >

# %% [markdown]
# **Here hist() is used to plot histogram of the parameter or coloumn age in the dataset and the figure represents it.**

# %%
df['age'].value_counts().plot(kind = 'bar', 
                                 figsize = (12, 5), 
                                 title = 'Distribution', 
                                 cmap = 'ocean')
# Out:
# <Axes: title={'center': 'Distribution'}, xlabel='age'>

# %% [markdown]
# **Here plot is used for the better visualization and it counts the values in the code and by using the count function counting happens and plot is of type bar with a heading distribution.**

# %%
df['country'].value_counts()
# Out:
# country
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %% [markdown]
# **Here in the dataset we are taking country as a parameter and we are counting the no of same country ones whether they is single country  or there are multiple ones and the output is shown above**

# %%
df["country"].hist()
# Out:
# <Axes: >

# %% [markdown]
# **Here hist() is used to plot histogram of the parameter or coloumn country in the dataset and the figure represents it.**

# %%
df['country'].value_counts().plot(kind = 'bar', 
                                 figsize = (12, 5), 
                                 title = 'Distribution', 
                                 cmap = 'ocean')
# Out:
# <Axes: title={'center': 'Distribution'}, xlabel='country'>

# %% [markdown]
# **Here plot is used for the better visualization and it counts the values in the code and by using the count function counting happens and plot is of type bar with a heading distribution.**

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %% [markdown]
# **Here in the dataset we are taking gender as a parameter and we are counting the no of same gender ones whether they is single gender people or there are multiple ones and the output is shown above**

# %%
df["gender"].hist()
# Out:
# <Axes: >

# %% [markdown]
# **Here hist() is used to plot histogram of the parameter or coloumn gender in the dataset and the figure represents it.**

# %%
df['gender'].value_counts().plot(kind = 'bar', 
                                 figsize = (12, 5), 
                                 title = 'Distribution', 
                                 cmap = 'ocean')
# Out:
# <Axes: title={'center': 'Distribution'}, xlabel='gender'>

# %% [markdown]
# **Here plot is used for the better visualization and it counts the values in the code and by using the count function counting happens and plot is of type bar with a heading distribution.**

# %%
df["churn"].hist()
# Out:
# <Axes: >

# %% [markdown]
# **Here hist() is used to plot histogram of the parameter or coloumn gender in the dataset and the figure represents it.**

# %%
df['churn'].value_counts().plot(kind = 'bar', 
                                 figsize = (12, 5), 
                                 title = 'Distribution', 
                                 cmap = 'ocean')
# Out:
# <Axes: title={'center': 'Distribution'}, xlabel='churn'>

# %% [markdown]
# **Here plot is used for the better visualization and it counts the values in the code and by using the count function counting happens and plot is of type bar with a heading distribution.**

# %%
plt.scatter(df.credit_score,df.age)
plt.show()

# %% [markdown]
# **Here,scatter function is used with plt including labels of x-axis and y-axis inside the brackets and by it sacattering plot occurs and by executing and using show method we will get the output as shown in the above figure,A scatter plot identifies a possible relationship between changes observed in two different sets of variables**

# %%
df['gender'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **It shows the distribution of the male and female in the plot diagram.**

# %%
df['churn'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **It shows the distribution of the churn and non-churn in the plot diagram.**
